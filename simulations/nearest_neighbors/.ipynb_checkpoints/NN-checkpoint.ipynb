# %%
import sys
import numpy as np
import pandas as pd
import scipy.stats as stats
from sklearn.neighbors import kneighbors_graph
import time

import scipy.sparse as sparse
from scipy.stats import multivariate_normal

# %matplotlib inline
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (7,7) # Make the figures a bit bigger

# %%
#generate points
d = 2  #dimension
n = 200 #number of point
n_neighbors = 5

V = np.random.random(n*d).reshape(n,d)
NN = kneighbors_graph(V, n_neighbors, mode='distance').nonzero()

# %%
S = np.random.random(n*d)
NN_s = kneighbors_graph(S, n_neighbors = 1, mode='distance').nonzero()
# Out:
# C:\Users\Majdi\Anaconda3\lib\site-packages\sklearn\utils\validation.py:386: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and willraise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-39-6ea75c37c04b> in <module>()
#       1 S = np.random.random(n*d)
# ----> 2 NN_s = kneighbors_graph(S, n_neighbors = 0, mode='distance').nonzero()
#
# C:\Users\Majdi\Anaconda3\lib\site-packages\sklearn\neighbors\graph.py in kneighbors_graph(X, n_neighbors, mode, metric, p, metric_params, include_self)
#     110     if not isinstance(X, KNeighborsMixin):
#     111         X = NearestNeighbors(n_neighbors, metric=metric, p=p,
# --> 112                              metric_params=metric_params).fit(X)
#     113     else:
#     114         _check_params(X, metric, p, metric_params)
#
# C:\Users\Majdi\Anaconda3\lib\site-packages\sklearn\neighbors\base.py in fit(self, X, y)
#     814             or [n_samples, n_samples] if metric='precomputed'.
#     815         """
# --> 816         return self._fit(X)
#
# C:\Users\Majdi\Anaconda3\lib\site-packages\sklearn\neighbors\base.py in _fit(self, X)
#     271                 raise ValueError(
#     272                     "Expected n_neighbors > 0. Got %d" %
# --> 273                     self.n_neighbors
#     274                 )
#     275
#
# ValueError: Expected n_neighbors > 0. Got 0

# %%
for k in range(n * n_neighbors):
    vertex_start = NN[0][k]
    vertex_end = NN[1][k]
    vertex_start_x = V[vertex_start,0]
    vertex_start_y = V[vertex_start,1]
    vertex_end_x = V[vertex_end,0]
    vertex_end_y = V[vertex_end,1]
    plt.plot([vertex_start_x,vertex_end_x], [vertex_start_y,vertex_end_y], "r-")
    
plt.scatter(V[:,0], V[:,1], s = 50, c="blue")

# %%
#create a sparse matrix and put a 1 for each nearest neighbors
Delta = sparse.lil_matrix((n,n))
for k in range(n * n_neighbors):
    Delta[NN[0][k], NN[0][k]] = 1

# %%
Delta
# Out:
# <200x200 sparse matrix of type '<class 'numpy.float64'>'
# 	with 200 stored elements in LInked List format>
